# %% [markdown]
# # Data Stories

# %%
import plotly.graph_objs as go
import pandas as pd

# %%
life_expectancy_df = pd.read_csv('datasets_71509_948751_life_expectancy.csv')
life_expectancy_df.head(5)
# Out:
#                             Neighborhood  2006-2010  2007-2011  2008-2012  \
# 0                               el Raval       87.5       84.9       84.7
# 1                         el Barri Gòtic       88.0       84.3       84.4
# 2                         la Barceloneta       88.2       85.3       84.4
# 3  Sant Pere, Santa Caterina i la Ribera       88.9       85.9       86.1
# 4                          el Fort Pienc       89.7       87.1       87.2
#
#    2009-2013  2010-2014  Gender
# 0       84.9       85.3  Female
# 1       87.5       84.4  Female
# 2       86.3       84.7  Female
# 3       85.5       85.3  Female
# 4       87.7       86.7  Female

# %%
accidents_df = pd.read_csv('accidents_2017.csv')
accidents_df = accidents_df[accidents_df["Neighborhood Name"] != "Unknown"]
accidents_df[accidents_df['Neighborhood Name'] == 'el Raval']
# Out:
#                    Id District Name Neighborhood Name  \
# 160   2017S004394      Ciutat Vella          el Raval
# 161   2017S009532      Ciutat Vella          el Raval
# 162   2017S005486      Ciutat Vella          el Raval
# 163   2017S005824      Ciutat Vella          el Raval
# 164   2017S003530      Ciutat Vella          el Raval
# ...               ...           ...               ...
# 9269  2017S007067      Ciutat Vella          el Raval
# 9270  2017S004744      Ciutat Vella          el Raval
# 9271  2017S009222      Ciutat Vella          el Raval
# 9272  2017S000752      Ciutat Vella          el Raval
# 9273  2017S002052      Ciutat Vella          el Raval
#
#                                                  Street    Weekday     Month  \
# 160   Josep Carner / Drassanes                      ...   Thursday       May
# 161   Carme                                         ...   Thursday  November
# 162   Nou de la Rambla                              ...     Friday      June
# ...

# %%
unemployment_df = pd.read_csv('unemployment.csv')
unemployment_df.head(5)
# Out:
#    Year    Month  District Code District Name  Neighborhood Code  \
# 0  2017  January              1  Ciutat Vella                  1
# 1  2017  January              1  Ciutat Vella                  2
# 2  2017  January              1  Ciutat Vella                  3
# 3  2017  January              1  Ciutat Vella                  4
# 4  2017  January              2      Eixample                  5
#
#                        Neighborhood Name Gender      Demand_occupation  Number
# 0                               el Raval   Male  Registered unemployed    2107
# 1                         el Barri Gòtic   Male  Registered unemployed     538
# 2                         la Barceloneta   Male  Registered unemployed     537
# 3  Sant Pere, Santa Caterina i la Ribera   Male  Registered unemployed     741
# 4                          el Fort Pienc   Male  Registered unemployed     630

# %% [markdown]
# ## Hallo
